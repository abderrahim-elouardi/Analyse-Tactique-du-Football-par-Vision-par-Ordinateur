# %%
# !pip install deep-sort-realtime
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: deep-sort-realtime in C:\Users\Mehdi\AppData\Roaming\Python\Python313\site-packages (1.3.2)
# Requirement already satisfied: numpy in C:\Users\Mehdi\AppData\Roaming\Python\Python313\site-packages (from deep-sort-realtime) (2.2.6)
# Requirement already satisfied: scipy in C:\Users\Mehdi\AppData\Roaming\Python\Python313\site-packages (from deep-sort-realtime) (1.17.1)
# Requirement already satisfied: opencv-python in C:\Python313\Lib\site-packages (from deep-sort-realtime) (4.13.0.92)

# %%
import cv2
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
from sklearn.cluster import KMeans
import numpy as np

# %%
# Load YOLO model
model = YOLO(r"..\fine_tunning_3\runs\detect\train\weights\best.pt")

# %%
# Initialize DeepSORT
tracker = DeepSort(
    max_age=5,
    n_init=5,
    max_iou_distance=0.7,
    max_cosine_distance=0.3,
    bgr=True
)
# Out:
# C:\Users\Mehdi\AppData\Roaming\Python\Python313\site-packages\deep_sort_realtime\embedder\embedder_pytorch.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
# Open video
cap = cv2.VideoCapture(r"..\video1.mp4")

fps = int(cap.get(cv2.CAP_PROP_FPS))
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

out = cv2.VideoWriter(
    r".\tracking_result2.mp4",
    cv2.VideoWriter_fourcc(*'mp4v'),
    fps,
    (frame_width, frame_height)
)

# %%
def get_color_histogram(crop, bins=(8, 8, 8)):

    if crop is None:
        print("crop is None")
        return None

    if crop.size == 0:
        print("crop is empty")
        return None

    h, w = crop.shape[:2]

    print(f"Crop size: {w} x {h}")

    if h < 10 or w < 10:
        print("Crop too small")
        return None

    y1 = int(h * 0.20)
    y2 = int(h * 0.60)

    x1 = int(w * 0.20)
    x2 = int(w * 0.80)

    torso = crop[y1:y2, x1:x2]

    print("Torso shape:", torso.shape)

    if torso.size == 0:
        print("Torso empty")
        return None

    hsv = cv2.cvtColor(torso, cv2.COLOR_BGR2HSV)

    hist = cv2.calcHist(
        [hsv],
        [0,1,2],
        None,
        bins,
        [0,180,0,256,0,256]
    )

    hist = cv2.normalize(hist, hist).flatten()

    print("Histogram shape:", hist.shape)

    return hist

# %%
player_features = {}      # track_id -> histogram
team_memory = {}          # track_id -> Team 1 / Team 2
clustering_done = False

while cap.isOpened():

    ret, frame = cap.read()

    if not ret:
        break

    # ---------------- YOLO ----------------
    results = model(frame, conf=0.3, iou=0.5)

    detections = []

    for result in results:

        for box in result.boxes:

            x1, y1, x2, y2 = box.xyxy[0].tolist()

            conf = float(box.conf[0])
            cls = int(box.cls[0])

            w = x2 - x1
            h = y2 - y1

            detections.append(
                (
                    [x1, y1, w, h],
                    conf,
                    cls
                )
            )

    # ---------------- DeepSORT ----------------
    tracks = tracker.update_tracks(
        detections,
        frame=frame
    )

    # ---------------- Tracking ----------------
    for track in tracks:

        if not track.is_confirmed():
            continue

        track_id = track.track_id

        class_id = track.get_det_class()
        class_name = model.names[class_id]

        l, t, r, b = map(int, track.to_ltrb())

        # Empêcher les coordonnées négatives
        l = max(0, l)
        t = max(0, t)
        r = min(frame.shape[1], r)
        b = min(frame.shape[0], b)

        # ---------------- Player Feature Extraction ----------------
        if class_name == "Player":

            if track_id not in player_features:

                clustering_done = False

                player_crop = frame[t:b, l:r]

                if player_crop.size != 0:
                    player_hist = get_color_histogram(player_crop)
                    
                if player_hist is not None:
                    player_features[track_id] = player_hist

        # ---------------- Draw ----------------

        if track_id in team_memory:
            label = f"{team_memory[track_id]} | ID:{track_id}"
        else:
            label = f"{class_name} | ID:{track_id}"

        cv2.rectangle(
            frame,
            (l, t),
            (r, b),
            (0, 255, 0),
            2
        )

        cv2.putText(
            frame,
            label,
            (l, t - 10),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.6,
            (0, 255, 0),
            2
        )

    # ---------------- KMeans ----------------

    if not clustering_done and len(player_features) >= 18:

        ids = list(player_features.keys())

        features = np.array(list(player_features.values()))

        kmeans = KMeans(
            n_clusters=2,
            random_state=42,
            n_init="auto"
        )

        labels = kmeans.fit_predict(features)

        for track_id, cluster in zip(ids, labels):

            if cluster == 0:
                team_memory[track_id] = "Team A"
            else:
                team_memory[track_id] = "Team B"

        clustering_done = True

        print("Players clustered successfully!")

    out.write(frame)

    cv2.imshow("Tracking", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 Keeper, 18 Players, 2 Refs, 111.9ms
# Speed: 3.0ms preprocess, 111.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 18 Players, 2 Refs, 67.7ms
# Speed: 3.4ms preprocess, 67.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 2 Refs, 66.4ms
# Speed: 3.1ms preprocess, 66.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 67.1ms
# Speed: 5.0ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 53.5ms
# Speed: 3.3ms preprocess, 53.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Crop size: 19 x 32
# High Torso shape: (10, 10, 3)
# Torso contains only green pelouse!
# Robust feature vector shape: (256,)
# Player
# Crop size: 20 x 42
# High Torso shape: (12, 10, 3)
# Robust feature vector shape: (256,)
# Player
# Crop size: 13 x 34
# High Torso shape: (10, 6, 3)
# Robust feature vector shape: (256,)
# Player
# Crop size: 16 x 35
# High Torso shape: (10, 8, 3)
# Robust feature vector shape: (256,)
# Keeper
# Player
# Crop size: 15 x 42
# High Torso shape: (12, 8, 3)
# Robust feature vector shape: (256,)
# Player
# Crop size: 12 x 31
# High Torso shape: (9, 6, 3)
# Robust feature vector shape: (256,)
# Player
# Crop size: 13 x 36
# High Torso shape: (11, 6, 3)
# Robust feature vector shape: (256,)
# Player
# Crop size: 15 x 31
# High Torso shape: (9, 8, 3)
# Robust feature vector shape: (256,)
# Ref
# Player
# Crop size: 14 x 36
# High Torso shape: (11, 7, 3)
# Robust feature vector shape: (256,)
# Player
# Crop size: 14 x 35
# High Torso shape: (10, 7, 3)
# Robust feature vector shape: (256,)
# Player
# Crop size: 16 x 36
# High Torso shape: (11, 8, 3)
# Robust feature vector shape: (256,)
# Player
# Crop size: 12 x 29
# High Torso shape: (9, 6, 3)
# Robust feature vector shape: (256,)
# Player
# Crop size: 13 x 40
# High Torso shape: (12, 6, 3)
# Robust feature vector shape: (256,)
# Player
# Crop size: 14 x 35
# High Torso shape: (10, 7, 3)
# Robust feature vector shape: (256,)
# Player
# Crop size: 16 x 33
# High Torso shape: (10, 8, 3)
# Robust feature vector shape: (256,)
# Player
# Crop size: 14 x 29
# High Torso shape: (9, 7, 3)
# Robust feature vector shape: (256,)
# Player
# Crop size: 20 x 36
# High Torso shape: (11, 10, 3)
# Robust feature vector shape: (256,)
# Player
# Crop size: 17 x 36
# High Torso shape: (11, 8, 3)
# Robust feature vector shape: (256,)
# Players clustered successfully!
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 63.8ms
# Speed: 4.1ms preprocess, 63.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 59.9ms
# Speed: 2.2ms preprocess, 59.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Crop size: 17 x 36
# High Torso shape: (11, 8, 3)
# Robust feature vector shape: (256,)
# Players clustered successfully!
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 54.3ms
# Speed: 2.1ms preprocess, 54.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 54.2ms
# Speed: 2.3ms preprocess, 54.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 55.2ms
# Speed: 2.3ms preprocess, 55.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 54.8ms
# Speed: 2.0ms preprocess, 54.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 19 Players, 1 Ref, 53.4ms
# Speed: 2.6ms preprocess, 53.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 19 Players, 1 Ref, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 19 Players, 1 Ref, 79.6ms
# Speed: 2.1ms preprocess, 79.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 52.4ms
# Speed: 1.7ms preprocess, 52.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 55.1ms
# Speed: 3.7ms preprocess, 55.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 64.2ms
# Speed: 2.8ms preprocess, 64.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 54.1ms
# Speed: 2.2ms preprocess, 54.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 20 Players, 1 Ref, 55.5ms
# Speed: 1.9ms preprocess, 55.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 55.4ms
# Speed: 2.1ms preprocess, 55.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 20 Players, 1 Ref, 54.3ms
# Speed: 2.4ms preprocess, 54.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 57.1ms
# Speed: 3.9ms preprocess, 57.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 53.7ms
# Speed: 2.4ms preprocess, 53.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 65.6ms
# Speed: 2.2ms preprocess, 65.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 55.6ms
# Speed: 2.3ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Crop size: 12 x 37
# High Torso shape: (11, 6, 3)
# Torso contains only green pelouse!
# Robust feature vector shape: (256,)
# Sécurité activée : Entraînement tardif du RandomForest à la Frame 25...
# Players clustered successfully!
#
# 0: 384x640 1 Keeper, 19 Players, 1 Ref, 78.6ms
# Speed: 3.8ms preprocess, 78.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 75.6ms
# Speed: 5.2ms preprocess, 75.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 69.3ms
# Speed: 3.6ms preprocess, 69.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 104.2ms
# Speed: 3.0ms preprocess, 104.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 78.9ms
# Speed: 2.9ms preprocess, 78.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 68.3ms
# Speed: 3.7ms preprocess, 68.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 124.1ms
# Speed: 4.3ms preprocess, 124.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 131.9ms
# Speed: 4.2ms preprocess, 131.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 119.6ms
# Speed: 3.2ms preprocess, 119.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 80.3ms
# Speed: 3.0ms preprocess, 80.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 74.1ms
# Speed: 3.1ms preprocess, 74.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 97.2ms
# Speed: 3.0ms preprocess, 97.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 3 Refs, 71.9ms
# Speed: 3.5ms preprocess, 71.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 77.0ms
# Speed: 3.6ms preprocess, 77.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 73.3ms
# Speed: 3.1ms preprocess, 73.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 73.1ms
# Speed: 2.8ms preprocess, 73.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 64.0ms
# Speed: 4.1ms preprocess, 64.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 81.5ms
# Speed: 2.5ms preprocess, 81.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 64.6ms
# Speed: 3.0ms preprocess, 64.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 70.0ms
# Speed: 2.7ms preprocess, 70.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 74.9ms
# Speed: 3.2ms preprocess, 74.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 66.9ms
# Speed: 2.6ms preprocess, 66.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 104.9ms
# Speed: 3.9ms preprocess, 104.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Player
# Crop size: 13 x 32
# High Torso shape: (10, 6, 3)
# Torso contains only green pelouse!
# Robust feature vector shape: (256,)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Prédiction via Random Forest (Frame 48)
# Players clustered successfully!
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 57.4ms
# Speed: 2.1ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 71.3ms
# Speed: 2.1ms preprocess, 71.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 70.5ms
# Speed: 5.8ms preprocess, 70.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 77.4ms
# Speed: 2.5ms preprocess, 77.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 65.1ms
# Speed: 4.2ms preprocess, 65.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 73.0ms
# Speed: 2.6ms preprocess, 73.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 86.3ms
# Speed: 2.7ms preprocess, 86.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 86.3ms
# Speed: 3.0ms preprocess, 86.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 66.8ms
# Speed: 3.6ms preprocess, 66.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Crop size: 13 x 24
# High Torso shape: (7, 6, 3)
# Robust feature vector shape: (256,)
# Ref
# Prédiction via Random Forest (Frame 57)
# Players clustered successfully!
#
# 0: 384x640 1 Keeper, 21 Players, 2 Refs, 55.0ms
# Speed: 2.3ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 21 Players, 2 Refs, 68.4ms
# Speed: 2.3ms preprocess, 68.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 63.7ms
# Speed: 2.7ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 55.2ms
# Speed: 3.1ms preprocess, 55.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 76.7ms
# Speed: 4.1ms preprocess, 76.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 112.6ms
# Speed: 3.8ms preprocess, 112.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 107.7ms
# Speed: 3.7ms preprocess, 107.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 148.2ms
# Speed: 5.2ms preprocess, 148.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 133.0ms
# Speed: 3.8ms preprocess, 133.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 108.9ms
# Speed: 4.3ms preprocess, 108.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 55.4ms
# Speed: 2.7ms preprocess, 55.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 119.6ms
# Speed: 4.9ms preprocess, 119.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 102.9ms
# Speed: 3.9ms preprocess, 102.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 20 Players, 1 Ref, 102.8ms
# Speed: 3.5ms preprocess, 102.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 20 Players, 1 Ref, 55.8ms
# Speed: 2.4ms preprocess, 55.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 54.6ms
# Speed: 2.8ms preprocess, 54.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 68.6ms
# Speed: 2.7ms preprocess, 68.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 54.2ms
# Speed: 2.3ms preprocess, 54.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 22 Players, 56.9ms
# Speed: 2.3ms preprocess, 56.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 52.8ms
# Speed: 3.7ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 88.9ms
# Speed: 4.8ms preprocess, 88.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 178.3ms
# Speed: 11.9ms preprocess, 178.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Crop size: 17 x 30
# High Torso shape: (9, 8, 3)
# Robust feature vector shape: (256,)
# Prédiction via Random Forest (Frame 79)
# Players clustered successfully!
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 144.2ms
# Speed: 4.6ms preprocess, 144.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 509.7ms
# Speed: 5.5ms preprocess, 509.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 157.3ms
# Speed: 4.3ms preprocess, 157.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 129.0ms
# Speed: 3.3ms preprocess, 129.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 66.6ms
# Speed: 2.8ms preprocess, 66.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 55.3ms
# Speed: 2.9ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 86.3ms
# Speed: 3.3ms preprocess, 86.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 80.7ms
# Speed: 3.4ms preprocess, 80.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 140.2ms
# Speed: 4.3ms preprocess, 140.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 110.7ms
# Speed: 4.7ms preprocess, 110.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 57.4ms
# Speed: 2.9ms preprocess, 57.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 60.8ms
# Speed: 2.5ms preprocess, 60.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 55.6ms
# Speed: 2.7ms preprocess, 55.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 88.3ms
# Speed: 4.3ms preprocess, 88.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 102.5ms
# Speed: 3.3ms preprocess, 102.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 2 Refs, 77.0ms
# Speed: 2.1ms preprocess, 77.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 2 Refs, 56.8ms
# Speed: 3.1ms preprocess, 56.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 75.7ms
# Speed: 3.5ms preprocess, 75.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ball
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 123.8ms
# Speed: 3.2ms preprocess, 123.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ball
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 58.8ms
# Speed: 2.9ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ball
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 96.3ms
# Speed: 3.8ms preprocess, 96.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ball
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 61.3ms
# Speed: 2.2ms preprocess, 61.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ball
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 62.1ms
# Speed: 2.7ms preprocess, 62.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ball
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 60.8ms
# Speed: 3.2ms preprocess, 60.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ball
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 117.1ms
# Speed: 7.0ms preprocess, 117.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 65.5ms
# Speed: 2.5ms preprocess, 65.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 54.6ms
# Speed: 3.2ms preprocess, 54.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 58.2ms
# Speed: 2.2ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 69.5ms
# Speed: 2.7ms preprocess, 69.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 71.9ms
# Speed: 2.5ms preprocess, 71.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 55.7ms
# Speed: 2.8ms preprocess, 55.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 57.4ms
# Speed: 3.0ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 56.9ms
# Speed: 2.4ms preprocess, 56.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 64.1ms
# Speed: 4.4ms preprocess, 64.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 56.6ms
# Speed: 3.4ms preprocess, 56.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 55.5ms
# Speed: 2.6ms preprocess, 55.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 54.9ms
# Speed: 2.8ms preprocess, 54.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 59.1ms
# Speed: 3.0ms preprocess, 59.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 2 Refs, 57.4ms
# Speed: 2.9ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 60.9ms
# Speed: 3.0ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 59.7ms
# Speed: 2.7ms preprocess, 59.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 57.9ms
# Speed: 2.4ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 59.5ms
# Speed: 2.5ms preprocess, 59.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 57.3ms
# Speed: 3.1ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 1 Ref, 59.7ms
# Speed: 2.6ms preprocess, 59.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 1 Ref, 60.7ms
# Speed: 2.6ms preprocess, 60.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 2 Refs, 59.6ms
# Speed: 2.6ms preprocess, 59.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 2 Refs, 59.7ms
# Speed: 2.1ms preprocess, 59.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 2 Refs, 97.0ms
# Speed: 2.6ms preprocess, 97.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 1 Ref, 61.1ms
# Speed: 2.4ms preprocess, 61.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 1 Ref, 113.5ms
# Speed: 4.3ms preprocess, 113.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 1 Ref, 57.8ms
# Speed: 2.3ms preprocess, 57.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 1 Ref, 61.6ms
# Speed: 4.2ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 1 Ref, 55.0ms
# Speed: 2.4ms preprocess, 55.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 20 Players, 1 Ref, 121.4ms
# Speed: 3.9ms preprocess, 121.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 20 Players, 1 Ref, 60.1ms
# Speed: 2.7ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 20 Players, 1 Ref, 92.7ms
# Speed: 2.3ms preprocess, 92.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 20 Players, 1 Ref, 57.2ms
# Speed: 2.3ms preprocess, 57.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 19 Players, 1 Ref, 61.2ms
# Speed: 2.4ms preprocess, 61.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 19 Players, 1 Ref, 123.3ms
# Speed: 5.1ms preprocess, 123.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 19 Players, 1 Ref, 62.0ms
# Speed: 2.7ms preprocess, 62.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 19 Players, 1 Ref, 63.8ms
# Speed: 2.9ms preprocess, 63.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 19 Players, 2 Refs, 131.5ms
# Speed: 4.8ms preprocess, 131.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 19 Players, 2 Refs, 111.6ms
# Speed: 2.1ms preprocess, 111.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
#
# 0: 384x640 1 Keeper, 19 Players, 2 Refs, 61.2ms
# Speed: 2.8ms preprocess, 61.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
#
# 0: 384x640 1 Keeper, 18 Players, 3 Refs, 118.2ms
# Speed: 3.2ms preprocess, 118.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
#
# 0: 384x640 1 Keeper, 19 Players, 2 Refs, 96.5ms
# Speed: 2.6ms preprocess, 96.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Ref
#
# 0: 384x640 1 Keeper, 19 Players, 1 Ref, 73.7ms
# Speed: 2.2ms preprocess, 73.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Ref
#
# 0: 384x640 1 Keeper, 19 Players, 1 Ref, 75.6ms
# Speed: 4.0ms preprocess, 75.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Ref
#
# 0: 384x640 1 Keeper, 19 Players, 1 Ref, 60.0ms
# Speed: 3.3ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Ref
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 58.8ms
# Speed: 3.3ms preprocess, 58.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Ref
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 63.3ms
# Speed: 2.6ms preprocess, 63.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Ref
# Player
# Crop size: 13 x 36
# High Torso shape: (11, 6, 3)
# Robust feature vector shape: (256,)
# Prédiction via Random Forest (Frame 151)
# Players clustered successfully!
#
# 0: 384x640 20 Players, 1 Ref, 61.0ms
# Speed: 2.5ms preprocess, 61.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 60.4ms
# Speed: 2.8ms preprocess, 60.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Ref
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 62.0ms
# Speed: 2.6ms preprocess, 62.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Ref
# Player
# ...
#
# 0: 384x640 20 Players, 1 Ref, 69.4ms
# Speed: 4.7ms preprocess, 69.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
#
# 0: 384x640 20 Players, 1 Ref, 87.7ms
# Speed: 3.4ms preprocess, 87.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 77.2ms
# Speed: 4.0ms preprocess, 77.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 20 Players, 94.1ms
# Speed: 4.8ms preprocess, 94.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 20 Players, 83.9ms
# Speed: 6.3ms preprocess, 83.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 20 Players, 74.3ms
# Speed: 3.5ms preprocess, 74.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 20 Players, 59.4ms
# Speed: 2.8ms preprocess, 59.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 65.3ms
# Speed: 2.8ms preprocess, 65.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 84.6ms
# Speed: 5.0ms preprocess, 84.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 20 Players, 125.2ms
# Speed: 4.4ms preprocess, 125.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 20 Players, 71.9ms
# Speed: 4.9ms preprocess, 71.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 20 Players, 1 Ref, 84.1ms
# Speed: 4.4ms preprocess, 84.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 20 Players, 1 Ref, 103.1ms
# Speed: 5.5ms preprocess, 103.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 20 Players, 1 Ref, 77.9ms
# Speed: 4.0ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 66.7ms
# Speed: 4.7ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 69.6ms
# Speed: 2.7ms preprocess, 69.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 67.2ms
# Speed: 5.3ms preprocess, 67.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 21 Players, 103.4ms
# Speed: 5.2ms preprocess, 103.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Keeper, 22 Players, 91.4ms
# Speed: 4.7ms preprocess, 91.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
# Crop size: 21 x 33
# High Torso shape: (10, 10, 3)
# Robust feature vector shape: (256,)
# Prédiction via Random Forest (Frame 355)
# Players clustered successfully!
#
# 0: 384x640 1 Ball, 1 Keeper, 22 Players, 79.9ms
# Speed: 21.4ms preprocess, 79.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Player
# Player
# Player
# Ref
# Player
#
# 0: 384x640 1 Keeper, 22 Players, 80.1ms
# Speed: 5.9ms preprocess, 80.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Keeper
#
# 0: 384x640 1 Keeper, 22 Players, 84.3ms
# Speed: 5.0ms preprocess, 84.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
#
# 0: 384x640 22 Players, 105.0ms
# Speed: 3.1ms preprocess, 105.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Crop size: 13 x 30
# High Torso shape: (9, 6, 3)
# Torso contains only green pelouse!
# Robust feature vector shape: (256,)
# Prédiction via Random Forest (Frame 359)
# Players clustered successfully!
#
# 0: 384x640 22 Players, 99.4ms
# Speed: 5.3ms preprocess, 99.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 21 Players, 89.4ms
# Speed: 6.2ms preprocess, 89.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 131.6ms
# Speed: 5.4ms preprocess, 131.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 97.3ms
# Speed: 4.6ms preprocess, 97.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 93.7ms
# Speed: 4.7ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 124.8ms
# Speed: 5.8ms preprocess, 124.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 1 Ref, 137.9ms
# Speed: 6.1ms preprocess, 137.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 128.3ms
# Speed: 4.7ms preprocess, 128.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 1 Ref, 99.8ms
# Speed: 5.1ms preprocess, 99.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 1 Ref, 110.3ms
# Speed: 6.8ms preprocess, 110.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 107.8ms
# Speed: 5.2ms preprocess, 107.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Ball, 21 Players, 1 Ref, 136.8ms
# Speed: 4.6ms preprocess, 136.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 1 Ref, 106.0ms
# Speed: 2.3ms preprocess, 106.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 1 Ref, 99.3ms
# Speed: 5.4ms preprocess, 99.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 115.9ms
# Speed: 6.9ms preprocess, 115.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
#
# 0: 384x640 21 Players, 1 Ref, 101.6ms
# Speed: 4.1ms preprocess, 101.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Ball, 21 Players, 1 Ref, 108.6ms
# Speed: 4.4ms preprocess, 108.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Ball, 21 Players, 1 Ref, 104.6ms
# Speed: 4.8ms preprocess, 104.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 21 Players, 1 Ref, 134.6ms
# Speed: 5.7ms preprocess, 134.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 21 Players, 1 Ref, 144.3ms
# Speed: 4.9ms preprocess, 144.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 132.0ms
# Speed: 4.0ms preprocess, 132.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 104.2ms
# Speed: 4.6ms preprocess, 104.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Ball, 21 Players, 2 Refs, 107.0ms
# Speed: 4.7ms preprocess, 107.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Ball, 21 Players, 2 Refs, 104.5ms
# Speed: 5.0ms preprocess, 104.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Ball, 21 Players, 1 Ref, 97.1ms
# Speed: 4.3ms preprocess, 97.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
#
# 0: 384x640 1 Ball, 21 Players, 1 Ref, 103.5ms
# Speed: 4.6ms preprocess, 103.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Ball
#
# 0: 384x640 1 Ball, 21 Players, 1 Ref, 117.9ms
# Speed: 4.4ms preprocess, 117.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Ball
#
# 0: 384x640 21 Players, 1 Ref, 155.5ms
# Speed: 6.4ms preprocess, 155.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Ball
#
# 0: 384x640 21 Players, 1 Ref, 124.9ms
# Speed: 4.8ms preprocess, 124.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Ref
# Ball
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 92.7ms
# Speed: 4.5ms preprocess, 92.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Keeper
# Player
# Ref
# Ball
#
# 0: 384x640 1 Keeper, 19 Players, 2 Refs, 84.3ms
# Speed: 4.0ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
