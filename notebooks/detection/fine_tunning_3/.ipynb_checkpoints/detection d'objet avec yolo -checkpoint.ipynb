# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="VjAxZSEJru3p0Pij8zYu")
project = rf.workspace("mehdis-workspace-jupje").project("football-analyst-v2-v5tiv")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.12/dist-packages (1.3.12)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2026.6.17)
# Requirement already satisfied: idna>=3.7 in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.18)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy<2.5,>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pi-heif<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.4.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests_toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: typer<0.26,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.25.1)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (8.4.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (4.63.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->roboflow) (3.4.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (0.1.2)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Football-Analyst-v2-2 to yolov8:: 100%|██████████| 1089346/1089346 [00:14<00:00, 76273.73it/s]
# Extracting Dataset Version Zip to Football-Analyst-v2-2 in yolov8:: 100%|██████████| 16917/16917 [00:06<00:00, 2700.40it/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import yaml

# Lire le fichier généré par Roboflow
with open(f"{dataset.location}/data.yaml", 'r') as stream:
    data = yaml.safe_load(stream)
    print(data)
# print("Nombre de classes (nc) :", data['nc'])
# print("Noms des classes :", data['names'])
# Out:
# {'names': ['Ball', 'Keeper', 'Player', 'Ref'], 'nc': 4, 'roboflow': {'license': 'CC BY 4.0', 'project': 'football-analyst-v2-v5tiv', 'url': 'https://universe.roboflow.com/mehdis-workspace-jupje/football-analyst-v2-v5tiv/dataset/2', 'version': 2, 'workspace': 'mehdis-workspace-jupje'}, 'test': '../test/images', 'train': '../train/images', 'val': '../valid/images'}

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.88-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.26.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (13.610.43)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.6.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics) (1.5.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.88-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 31.1 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.88 ultralytics-thop-2.0.20

# %%
# Exemple de ce que vous feriez juste après :
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/best.pt")  # Charge un modèle YOLOv8 natif
# model = YOLO("../fine-tunning2/runs/detect/train/weights/best.pt")  # Charge un modèle YOLOv8 natif
model.train(data=f"{dataset.location}/data.yaml", epochs=100)  # Lance l'entraînement !
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 from ultralytics import YOLO
#       4 model = YOLO("runs/detect/train/weights/best.pt")  # Charge un modèle YOLOv8 natif
# ----> 5 model.train(data=f"{dataset.location}/data.yaml", epochs=100)  # Lance l'entraînement !
#
# NameError: name 'dataset' is not defined

# %%
from ultralytics import YOLO
model = YOLO("../fine-tunning2/runs/detect/train/weights/best.pt")  # Charge un modèle YOLOv8 natif
resultat  = model("../../../data/extracted_frames/data1/frame_1_490.jpg")
resultat[0].show()
# Out:
# image 1/1 D:\MEHDI\Study\WISD\S2\Visual analytics\projet\Analyse-Tactique-du-Football-par-Vision-par-Ordinateur\notebooks\detection\fine_tunning_3\..\..\..\data\extracted_frames\data1\frame_1_490.jpg: 384x640 1 Ball, 1 Keeper, 23 Players, 1 Ref, 78.8ms
# Speed: 4.0ms preprocess, 78.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)

# %%
# 2. Lancer la validation exclusivement sur le jeu de test
metrics = model.val(split='val')

# 3. Afficher les résultats clés
print(f"mAP50-95 (Précision globale) : {metrics.box.map:.4f}")
print(f"mAP50 (Précision à seuil 0.5) : {metrics.box.map50:.4f}")
print(f"Précision par classe : {metrics.box.mp:.4f}")
print(f"Rappel (Recall) par classe : {metrics.box.mr:.4f}")

# Afficher les performances détaillées par classe
for i, name in enumerate(metrics.names.values()):
    print(f"--- Classe : {name} ---")
    print(f"  Précision (Precision) : {metrics.box.class_result(i)[0]:.4f}")
    print(f"  Rappel (Recall)       : {metrics.box.class_result(i)[1]:.4f}")
    print(f"  mAP50                 : {metrics.box.class_result(i)[2]:.4f}")
    print("-" * 25)
# Out:
# Ultralytics 8.4.88 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1825.4±708.5 MB/s, size: 157.7 KB)
# val: Scanning /content/Football-Analyst-v2-2/valid/labels.cache... 560 images, 35 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 560/560 130.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 3.1it/s 11.4s
#                    all        560       7173      0.879      0.619      0.688      0.417
#                   Ball        275        299      0.833      0.551      0.625       0.35
#                 Keeper        247        255      0.883      0.569      0.672      0.395
#                 Player        399       5963      0.931      0.717      0.747      0.494
#                    Ref        353        656      0.867      0.639      0.709      0.429
# Speed: 1.9ms preprocess, 4.4ms inference, 0.0ms loss, 3.1ms postprocess per image
# Results saved to /content/runs/detect/val-2
# mAP50-95 (Précision globale) : 0.4169
# mAP50 (Précision à seuil 0.5) : 0.6882
# Précision par classe : 0.8786
# Rappel (Recall) par classe : 0.6188
# --- Classe : Ball ---
#   Précision (Precision) : 0.8330
#   Rappel (Recall)       : 0.5506
#   mAP50                 : 0.6255
# -------------------------
# --- Classe : Keeper ---
#   Précision (Precision) : 0.8827
#   Rappel (Recall)       : 0.5686
#   mAP50                 : 0.6724
# -------------------------
# --- Classe : Player ---
#   Précision (Precision) : 0.9311
#   Rappel (Recall)       : 0.7174
#   mAP50                 : 0.7465
# -------------------------
# --- Classe : Ref ---
#   Précision (Precision) : 0.8675
#   Rappel (Recall)       : 0.6387
#   mAP50                 : 0.7085
# -------------------------

# %%
import cv2
from ultralytics import YOLO

model = YOLO(r"runs\detect\train\weights\best.pt")
cap = cv2.VideoCapture("../../../data/videos/video1.mp4")

# Récupérer les propriétés de la vidéo d'origine
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Créer le fichier de sortie
out = cv2.VideoWriter(r".\resultat_annote1.mp4", cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    resultats = model(frame)
    frame_annotee = resultats[0].plot()

    out.write(frame_annotee)        # écrit la frame dans le fichier vidéo
    cv2.imshow("Detection", frame_annotee)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 51.6ms
# Speed: 3.8ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 2 Refs, 58.9ms
# Speed: 2.0ms preprocess, 58.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 2 Refs, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 2 Refs, 58.0ms
# Speed: 1.8ms preprocess, 58.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 59.5ms
# Speed: 1.9ms preprocess, 59.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 50.6ms
# Speed: 1.8ms preprocess, 50.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 58.3ms
# Speed: 2.9ms preprocess, 58.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 58.1ms
# Speed: 1.9ms preprocess, 58.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 2 Refs, 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 84.0ms
# Speed: 2.7ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 70.5ms
# Speed: 2.5ms preprocess, 70.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 19 Players, 1 Ref, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 19 Players, 1 Ref, 64.6ms
# Speed: 2.0ms preprocess, 64.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 19 Players, 1 Ref, 62.2ms
# Speed: 3.2ms preprocess, 62.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 64.6ms
# Speed: 1.9ms preprocess, 64.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 61.8ms
# Speed: 1.6ms preprocess, 61.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 20 Players, 1 Ref, 57.7ms
# Speed: 3.7ms preprocess, 57.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 20 Players, 1 Ref, 61.0ms
# Speed: 2.1ms preprocess, 61.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 20 Players, 1 Ref, 56.7ms
# Speed: 3.2ms preprocess, 56.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 19 Players, 1 Ref, 63.8ms
# Speed: 2.6ms preprocess, 63.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 20 Players, 1 Ref, 58.5ms
# Speed: 2.3ms preprocess, 58.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 60.8ms
# Speed: 2.6ms preprocess, 60.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 72.0ms
# Speed: 2.4ms preprocess, 72.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 121.7ms
# Speed: 3.6ms preprocess, 121.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 76.3ms
# Speed: 2.9ms preprocess, 76.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 64.9ms
# Speed: 2.3ms preprocess, 64.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 67.0ms
# Speed: 2.2ms preprocess, 67.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 59.7ms
# Speed: 1.9ms preprocess, 59.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 2 Refs, 59.8ms
# Speed: 2.4ms preprocess, 59.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 58.3ms
# Speed: 3.3ms preprocess, 58.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 68.9ms
# Speed: 4.5ms preprocess, 68.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 64.2ms
# Speed: 2.0ms preprocess, 64.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 56.8ms
# Speed: 2.0ms preprocess, 56.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 62.0ms
# Speed: 1.9ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 65.1ms
# Speed: 2.9ms preprocess, 65.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 50.0ms
# Speed: 2.3ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 3 Refs, 51.1ms
# Speed: 2.3ms preprocess, 51.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 3 Refs, 50.0ms
# Speed: 2.6ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 3 Refs, 52.6ms
# Speed: 2.2ms preprocess, 52.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 53.1ms
# Speed: 2.1ms preprocess, 53.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 56.0ms
# Speed: 2.5ms preprocess, 56.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 53.8ms
# Speed: 3.0ms preprocess, 53.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 48.8ms
# Speed: 3.2ms preprocess, 48.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 49.9ms
# Speed: 1.9ms preprocess, 49.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 50.8ms
# Speed: 1.7ms preprocess, 50.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 51.4ms
# Speed: 2.2ms preprocess, 51.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 48.5ms
# Speed: 2.3ms preprocess, 48.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 49.8ms
# Speed: 1.7ms preprocess, 49.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 50.9ms
# Speed: 1.9ms preprocess, 50.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 50.4ms
# Speed: 2.0ms preprocess, 50.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 50.5ms
# Speed: 1.7ms preprocess, 50.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 2 Refs, 51.6ms
# Speed: 2.2ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 54.3ms
# Speed: 2.5ms preprocess, 54.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 23 Players, 1 Ref, 49.6ms
# Speed: 2.5ms preprocess, 49.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 22 Players, 1 Ref, 51.0ms
# Speed: 2.1ms preprocess, 51.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 2 Refs, 52.2ms
# Speed: 2.0ms preprocess, 52.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 22 Players, 2 Refs, 74.7ms
# Speed: 3.1ms preprocess, 74.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 23 Players, 2 Refs, 51.3ms
# Speed: 2.0ms preprocess, 51.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 50.8ms
# Speed: 1.7ms preprocess, 50.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 2 Refs, 48.2ms
# Speed: 1.9ms preprocess, 48.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 2 Refs, 60.4ms
# Speed: 2.9ms preprocess, 60.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 2 Refs, 60.5ms
# Speed: 1.9ms preprocess, 60.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 2 Refs, 56.2ms
# Speed: 3.0ms preprocess, 56.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 60.6ms
# Speed: 2.2ms preprocess, 60.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 60.9ms
# Speed: 3.1ms preprocess, 60.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 53.3ms
# Speed: 1.7ms preprocess, 53.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 50.9ms
# Speed: 1.8ms preprocess, 50.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 51.4ms
# Speed: 2.0ms preprocess, 51.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 48.6ms
# Speed: 1.8ms preprocess, 48.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 51.9ms
# Speed: 1.7ms preprocess, 51.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 50.0ms
# Speed: 1.8ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 20 Players, 1 Ref, 49.4ms
# Speed: 2.1ms preprocess, 49.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 48.0ms
# Speed: 2.7ms preprocess, 48.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 23 Players, 1 Ref, 51.6ms
# Speed: 2.1ms preprocess, 51.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 23 Players, 1 Ref, 49.7ms
# Speed: 1.7ms preprocess, 49.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 50.3ms
# Speed: 3.0ms preprocess, 50.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 54.9ms
# Speed: 2.1ms preprocess, 54.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 49.1ms
# Speed: 1.8ms preprocess, 49.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 23 Players, 1 Ref, 57.4ms
# Speed: 1.6ms preprocess, 57.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 22 Players, 1 Ref, 48.9ms
# Speed: 2.3ms preprocess, 48.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 22 Players, 1 Ref, 76.5ms
# Speed: 4.4ms preprocess, 76.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 22 Players, 1 Ref, 51.6ms
# Speed: 1.8ms preprocess, 51.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 22 Players, 2 Refs, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 2 Refs, 49.7ms
# Speed: 1.8ms preprocess, 49.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 49.1ms
# Speed: 2.7ms preprocess, 49.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 50.7ms
# Speed: 1.7ms preprocess, 50.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 56.0ms
# Speed: 2.5ms preprocess, 56.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 53.7ms
# Speed: 1.7ms preprocess, 53.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 55.5ms
# Speed: 1.8ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 50.5ms
# Speed: 1.7ms preprocess, 50.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 51.6ms
# Speed: 1.7ms preprocess, 51.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 50.9ms
# Speed: 1.8ms preprocess, 50.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 50.1ms
# Speed: 1.6ms preprocess, 50.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 2 Refs, 50.1ms
# Speed: 2.6ms preprocess, 50.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 2 Refs, 47.1ms
# Speed: 2.0ms preprocess, 47.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 59.9ms
# Speed: 1.8ms preprocess, 59.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 52.1ms
# Speed: 2.4ms preprocess, 52.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 51.0ms
# Speed: 1.8ms preprocess, 51.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 22 Players, 1 Ref, 80.5ms
# Speed: 1.9ms preprocess, 80.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 2 Refs, 54.8ms
# Speed: 2.1ms preprocess, 54.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Ball, 1 Keeper, 21 Players, 1 Ref, 55.7ms
# Speed: 1.9ms preprocess, 55.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 49.8ms
# Speed: 1.8ms preprocess, 49.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 51.5ms
# Speed: 1.9ms preprocess, 51.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 51.4ms
# Speed: 1.7ms preprocess, 51.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 50.7ms
# Speed: 1.7ms preprocess, 50.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 51.2ms
# Speed: 1.8ms preprocess, 51.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 23 Players, 48.9ms
# Speed: 2.7ms preprocess, 48.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 22 Players, 1 Ref, 52.0ms
# Speed: 1.7ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 22 Players, 1 Ref, 51.9ms
# Speed: 1.8ms preprocess, 51.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 22 Players, 1 Ref, 56.8ms
# Speed: 1.9ms preprocess, 56.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 56.2ms
# Speed: 2.6ms preprocess, 56.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 54.9ms
# Speed: 2.3ms preprocess, 54.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 57.9ms
# Speed: 2.7ms preprocess, 57.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 79.0ms
# Speed: 1.8ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 51.0ms
# Speed: 3.2ms preprocess, 51.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 49.0ms
# Speed: 1.7ms preprocess, 49.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 2 Refs, 52.1ms
# Speed: 1.6ms preprocess, 52.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 52.4ms
# Speed: 1.7ms preprocess, 52.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 51.2ms
# Speed: 2.0ms preprocess, 51.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 2 Refs, 49.7ms
# Speed: 2.5ms preprocess, 49.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Keeper, 21 Players, 1 Ref, 50.5ms
# Speed: 1.6ms preprocess, 50.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
