# %%
import cv2
from ultralytics import YOLO

model = YOLO(r"./best.pt")
cap = cv2.VideoCapture(r"./WhatsApp Video 2026-07-01 at 02.22.30.mp4")

# Récupérer les propriétés de la vidéo d'origine
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Créer le fichier de sortie
out = cv2.VideoWriter(r".\resultat_annote.mp4", cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    resultats = model(frame)
    frame_annotee = resultats[0].plot()

    out.write(frame_annotee)        # écrit la frame dans le fichier vidéo
    cv2.imshow("Detection", frame_annotee)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[5], line 4
#       1 import cv2
#       2 from ultralytics import YOLO
#       3
# ----> 4 model = YOLO(r"./best.pt")
#       5 cap = cv2.VideoCapture(r"./WhatsApp Video 2026-07-01 at 02.22.30.mp4")
#       6
#       7 # Récupérer les propriétés de la vidéo d'origine
#
# File c:\Users\HP\Documents\projects\Analyse-Tactique-du-Football-par-Vision-par-Ordinateur\.venv\Lib\site-packages\ultralytics\models\yolo\model.py:79, in YOLO.__init__(self, model, task, verbose)
#      76     self.__dict__ = new_instance.__dict__
#      77 else:
#      78     # Continue with default YOLO initialization
# ---> 79     super().__init__(model=model, task=task, verbose=verbose)
#      80     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      81         from ultralytics import RTDETR
#
# File c:\Users\HP\Documents\projects\Analyse-Tactique-du-Football-par-Vision-par-Ordinateur\.venv\Lib\site-packages\ultralytics\engine\model.py:144, in Model.__init__(self, model, task, verbose)
#     142     self._new(model, task=task, verbose=verbose)
#     143 else:
# --> 144     self._load(model, task=task)
#     146 # Delete super().training for accessing self.model.training
#     147 del self.training
#
# File c:\Users\HP\Documents\projects\Analyse-Tactique-du-Football-par-Vision-par-Ordinateur\.venv\Lib\site-packages\ultralytics\engine\model.py:283, in Model._load(self, weights, task)
#     280 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolo26n -> yolo26n.pt
#     282 if str(weights).rpartition(".")[-1] == "pt":
# --> 283     self.model, self.ckpt = load_checkpoint(weights)
#     284     self.task = self.model.task
#     285     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File c:\Users\HP\Documents\projects\Analyse-Tactique-du-Football-par-Vision-par-Ordinateur\.venv\Lib\site-packages\ultralytics\nn\tasks.py:1743, in load_checkpoint(weight, device, inplace, fuse)
#    1741 if str(weight).lower().startswith(REMOTE_FILE_PREFIXES):
#    1742     weight = check_file(weight, download_dir=SETTINGS["weights_dir"])
# -> 1743 ckpt, weight = torch_safe_load(weight)  # load ckpt
#    1744 args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#    1745 candidate = ckpt.get("ema") or ckpt.get("model")
#
# File c:\Users\HP\Documents\projects\Analyse-Tactique-du-Football-par-Vision-par-Ordinateur\.venv\Lib\site-packages\ultralytics\nn\tasks.py:1655, in torch_safe_load(weight, safe_only)
#    1652         return torch_load(file, map_location="cpu")
#    1654 try:
# -> 1655     ckpt = _load()
#    1657 except RuntimeError as e:
#    1658     # Recover only a corrupt cached official asset requested by bare name; never touch user-supplied paths.
#    1659     name = Path(str(weight)).name
#
# File c:\Users\HP\Documents\projects\Analyse-Tactique-du-Football-par-Vision-par-Ordinateur\.venv\Lib\site-packages\ultralytics\nn\tasks.py:1652, in torch_safe_load.<locals>._load()
#    1650     with _SafeLoad.loading():  # weights_only load scoped to the known-class allow-list
#    1651         return torch_load(file, map_location="cpu", weights_only=True)
# -> 1652 return torch_load(file, map_location="cpu")
#
# File c:\Users\HP\Documents\projects\Analyse-Tactique-du-Football-par-Vision-par-Ordinateur\.venv\Lib\site-packages\ultralytics\utils\patches.py:181, in torch_load(*args, **kwargs)
#     178 if TORCH_1_13 and "weights_only" not in kwargs:
#     179     kwargs["weights_only"] = False
# --> 181 return torch.load(*args, **kwargs)
#
# File c:\Users\HP\Documents\projects\Analyse-Tactique-du-Football-par-Vision-par-Ordinateur\.venv\Lib\site-packages\torch\serialization.py:1530, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1527 if "encoding" not in pickle_load_args:
#    1528     pickle_load_args["encoding"] = "utf-8"
# -> 1530 with _open_file_like(f, "rb") as opened_file:
#    1531     if _is_zipfile(opened_file):
#    1532         # The zipfile reader is going to advance the current file position.
#    1533         # If we want to actually tail call to torch.jit.load, we need to
#    1534         # reset back to the original position.
#    1535         orig_position = opened_file.tell()
#
# File c:\Users\HP\Documents\projects\Analyse-Tactique-du-Football-par-Vision-par-Ordinateur\.venv\Lib\site-packages\torch\serialization.py:795, in _open_file_like(name_or_buffer, mode)
#     793 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     794     if _is_path(name_or_buffer):
# --> 795         return _open_file(name_or_buffer, mode)
#     796     else:
#     797         if "w" in mode:
#
# File c:\Users\HP\Documents\projects\Analyse-Tactique-du-Football-par-Vision-par-Ordinateur\.venv\Lib\site-packages\torch\serialization.py:776, in _open_file.__init__(self, name, mode)
#     775 def __init__(self, name: str | os.PathLike[str], mode: str) -> None:
# --> 776     super().__init__(open(name, mode))
#
# PermissionError: [Errno 13] Permission denied: 'best.pt'
